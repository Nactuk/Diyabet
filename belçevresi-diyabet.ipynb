# %%
import pandas as p
import numpy as n
import seaborn as s
import statsmodels.api as sm
import matplotlib.pyplot as mp
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
veri=p.read_csv("C:/Users/egeca/Downloads/diabetes.csv", usecols=[5,16]).dropna()

# %%
veri.corr()
# Out:
#           glyhb     waist
# glyhb  1.000000  0.226184
# waist  0.226184  1.000000

# %%
s.pairplot(veri)

# %%
x=veri.waist
y=veri.glyhb
mp.scatter(x.values,y.values)
mp.xlabel('Bel Çevresi')
mp.ylabel('Diabet seviyesi')
mp.title('Bel çevresi ile Diabet arasındaki ilişki')
# Out:
# Text(0.5, 1.0, 'Bel çevresi ile Diabet arasındaki ilişki')

# %%
x_egit, x_test, y_egit, y_test=train_test_split(x,y,test_size=0.4, random_state=40)

# %%
print("Eğitim Boyutu:{}".format(len(x_egit)))
print("Test Boyutu:{}".format(len(x_test)))
# Out:
# Eğitim Boyutu:232
# Test Boyutu:156

# %%
x=sm.add_constant(x)
drgm=sm.OLS(y,x).fit()
print(drgm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  glyhb   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     20.81
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):           6.82e-06
# Time:                        15:15:53   Log-Likelihood:                -853.26
# No. Observations:                 388   AIC:                             1711.
# Df Residuals:                     386   BIC:                             1718.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2642      0.740      3.061      0.002       0.810       3.718
# ...
